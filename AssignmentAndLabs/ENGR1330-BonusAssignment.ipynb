# %% [markdown]
# # <font color=darkblue>Weekly Bonus Assignment</font>

# %% [markdown]
# ## Full name:
# ## R#:
# ## Title of the notebook:
# ## Date:

# %%
# Preamble script block to identify host, user, and kernel
import sys
! hostname
! whoami
print(sys.executable)
print(sys.version)
print(sys.version_info)

# %% [markdown]
# **Exercise-1: Import all the libraries - numpy, pandas, matplotlib, seaborn, and scikit-learn so that we do not have to worry about importing the libraries later on in this assignment.**
#
# **(2 Points)**

# %%
#GIVE YOUR ANSWER FOR EXERCISE-1 IN THIS CELL

# %% [markdown]
# **Exercise-2: We will be working with an ecommerce dataset to predict the customer’s yearly spending amount in dollars based on 4 features, namely, average session length in minutes (average in-store style advice sessions), time on app in minutes, time on website in minutes, length of membership in years. Specific tasks for this exercise are given below.**
#
# **(58 Points)**

# %% [markdown]
# **Task-1:** Read the **`EcommerceCustomers.csv`** file and store it in a variable named **`ecommerce`**. Display the first 5 rows of the dataframe **`ecommerce`**.

# %%
#GIVE YOUR ANSWER FOR TASK-1 IN THIS CELL

# %% [markdown]
# **Task-2:** Get the information (i.e, the number of rows and the data types present in each column) and the basic statistical measures about the dataframe **`ecommerce`** using the appropriate functions available in the Pandas library.

# %%
#GIVE YOUR ANSWER FOR TASK-2 IN THIS CELL

# %% [markdown]
# **Task-3:** Display the scatter plot between all the columns in the dataset using the appropriate plotting function in the Seaborn library.

# %%
#GIVE YOUR ANSWER FOR TASK-3 IN THIS CELL

# %% [markdown]
# **Task-4:** Compute the correlation coefficient between all the columns in the dataset using the appropriate function in the Pandas library and store it in a variable named **`corr`**. Display the heat map of correlation values stored in **`corr`** using the appropriate function in the Seaborn library. The heat map must display an appropriate title.

# %%
#GIVE YOUR ANSWER FOR TASK-4 IN THIS CELL

# %% [markdown]
# **Task-5:** Copy the original dataframe **`ecommerce`** to a variable named **`data`**. Use the copied dataframe **`data`** to index and pick only the columns of interest. Store the indexed columns again in the same variable named **`data`** and print the first 5 rows of the dataframe **`data`** to the output.
#
# **Hint:** **`iloc`** indexer in Pandas library might come in handy.

# %%
#GIVE YOUR ANSWER FOR TASK-5 IN THIS CELL

# %% [markdown]
# **Task-6:** Convert all the 4 features (first 4 columns) of interest into standard units and append each one of them as new columns named **`Avg. Session Length (standard units)`**, **`Time on App (standard units)`**, **`Time on Website (standard units)`**, and **`Length of Membership (standard units)`** to the dataframe **`data`**. After appending all the new columns, print the first 5 rows of the dataframe **`data`** to the output.

# %%
#GIVE YOUR ANSWER FOR TASK-6 IN THIS CELL

# %% [markdown]
# **Task-7:** Randomly shuffle (without replacement) all the rows in the dataframe **`data`**. After shuffling, pick the first 66.66% of the rows and store it in a variable named **`training_set`**. Pick the rest 33.33% of the rows and store it in a variable named **`test_set`**. Print the length of **`training_set`** and **`test_set`** to the output.

# %%
#GIVE YOUR ANSWER FOR TASK-7 IN THIS CELL

# %% [markdown]
# **Task-8:** Index and pick the 4 feature columns in standard units from the **`training_set`** and the **`test_set`**, and store them as NumPy arrays in variables named **`x_train`** and **`x_test`**, respectively. Similary, index and pick the column named **`Yearly Amount Spent`** from the **`training_set`** and the **`test_set`** and store them as NumPy arrays in variables named **`y_train`** and **`y_test`**. Make sure you convert **`y_train`** and **`y_test`** to a 2D NumPy array using the **`reshape()`** function in the NumPy library. Print the shape of **`x_train`**, **`x_test`**, **`y_train`**, and **`y_test`** to the output.
#
# **Hint:** **`iloc`** indexer in Pandas library might come in handy.

# %%
#GIVE YOUR ANSWER FOR TASK-8 IN THIS CELL

# %% [markdown]
# **Task-9:** Transpose **`x_train`** and store it in a variable named **`x_train_trans`**. Vertically stack a row of ones to **`x_train_trans`** and store it in a variable named **`x_train_Aug`**. Similarly, transpose **`x_test`** and store it in a variable named **`x_test_trans`**. Vertically stack a row of ones to **`x_test_trans`** and store it in a variable named **`x_test_Aug`**. Print the shape of **`x_train_Aug`** and **`x_test_Aug`** to the output.

# %%
#GIVE YOUR ANSWER FOR TASK-9 IN THIS CELL

# %% [markdown]
# **Task-10:** Create a 2D NumPy array of zeros with 5 rows and 1 column, and store it in a variable named **`theta`**. Print the shape of **`theta`** to the output.

# %%
#GIVE YOUR ANSWER FOR TASK-10 IN THIS CELL

# %% [markdown]
# **Task-11:** Implement the gradient descent algorithm and make it run for 10,000 iterations with a learning rate of 0.003. Make sure you append all the cost function values that you get during each of the 10,000 iterations to an empty list named **`costfunc`**. Print the length of **`costfunc`** and the final theta values stored in a variable named **`theta`** to the output.

# %%
#GIVE YOUR ANSWER FOR TASK-11 IN THIS CELL

# %% [markdown]
# **Task-12:** Predict the yearly amount spent using the theta values obtained in the previous task and **`x_train_Aug`**, and store the predicted values in a variable named **`h_theta`**. Transpose **`h_theta`** and store it in a variable named **`y_train_pred`**. Plot a scatter plot for **`y_train_pred`** vs. **`y_train`**. Also, draw a line plot using the minimum and maximum values of **`y_train`** and **`y_train_pred`**. The plot must diplay appropriate x-label, y-label, and title.

# %%
#GIVE YOUR ANSWER FOR TASK-12 IN THIS CELL

# %% [markdown]
# **Task-13:** Predict the yearly amount spent using the theta values obtained in the previous task and **`x_test_Aug`**, and store the predicted values in a variable named **`h_theta`**. Transpose **`h_theta`** and store it in a variable named **`y_test_pred`**. Plot a scatter plot for **`y_test_pred`** vs. **`y_test`**. Also, draw a line plot using the minimum and maximum values of **`y_test`** and **`y_test_pred`**. The plot must diplay appropriate x-label, y-label, and title.

# %%
#GIVE YOUR ANSWER FOR TASK-13 IN THIS CELL

# %% [markdown]
# **Task-14:** Make a line plot between the cost function values vs. number of iterations. The plot must diplay appropriate x-label, y-label, and title.

# %%
#GIVE YOUR ANSWER FOR TASK-14 IN THIS CELL

# %% [markdown]
# **Task-15:** Compute the MSE and the RMSE values between the **`y_train`** and **`y_train_pred`**, and store them in variables named **`MSE_train`** and **`RMSE_train`**, respectively. Print **`MSE_train`** and **`RMSE_train`** to the output.

# %%
#GIVE YOUR ANSWER FOR TASK-15 IN THIS CELL

# %% [markdown]
# **Task-16:** Compute the MSE and the RMSE values between the **`y_test`** and **`y_test_pred`**, and store them in variables named **`MSE_test`** and **`RMSE_test`**, respectively. Print **`MSE_test`** and **`RMSE_test`** to the output.

# %%
#GIVE YOUR ANSWER FOR TASK-16 IN THIS CELL
