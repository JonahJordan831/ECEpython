# %% [markdown]
# ## Assignment-1 (100 points)

# %% [markdown]
# **Jordan, Jonah**
#
# **R11886590**

# %%
# RUN this cell only, do not modify it
import sys
! hostname
! whoami
print(sys.executable)
print(sys.version)
print(sys.version_info)
# Out:
# Jonah_laptop
# jonah_laptop\jonah
# C:\Users\JONAH\anaconda3\python.exe
# 3.11.4 | packaged by Anaconda, Inc. | (main, Jul  5 2023, 13:38:37) [MSC v.1916 64 bit (AMD64)]
# sys.version_info(major=3, minor=11, micro=4, releaselevel='final', serial=0)

# %% [markdown]
# ## Lab session for variables, operators, expressions, basic I/O, and string manipulation

# %% [markdown]
# #### Exercise-1: Run the cell below

# %% [markdown]
# **(20 points)**

# %%
print('Sup World?')
print(3 + 2 )
print('3 + 2')
MyNumber = 3+2.0
MyName = 'Dusty'
print(MyName, MyNumber)
print('MyName', 'MyNumber')
# Out:
# Sup World?
# 5
# 3 + 2
# Dusty 5.0
# MyName MyNumber

# %% [markdown]
# **Answer the following questions based on the output**
#
# **1.  What is the difference between `print(3 + 2)` and `print('3 + 2')`?**
# **---print(3 + 2) is a mthmatical operation, using integers the result is 5.
# print('3 + 2') is a string, so it prints the characters '3 + 2' exactly asit is written , because it is not an int
# **2.  What is the difference between `print(MyName, MyNumber)` and `print('MyName', 'MyNumber')`?**
# **---print(MyName, MyNumber) prints the values of the variables MyName and MyNumber. so it prints "Dusty 5", since th variables are defined
# print('MyName', 'MyNumber')  prints the characters 'MyName' and 'MyNumber' exactly as they are because they are strings.
# **3.  Change `MyNumber = 3+2` to `MyNumber = 3+2.0`, and re-run the script, what happens? Why?**
# **---operations involving both int and float numbers will turn into a floatnumber. So the result of 3 + 2.0 is 5.0

# %% [markdown]
# **Write your answer in the markdown cell below:**

# %% [markdown]
# **-1)** print(3 + 2) is a mthmatical operation, using integers the result is 5.
# print('3 + 2') is a string, so it prints the characters '3 + 2' exactly asit is written , because it is not an int
# **-2)** print(MyName, MyNumber) prints the values of the variables MyName and MyNumber. so it prints "Dusty 5", since th variables are defined
# **-3)** operations involving both int and float numbers will turn into a floatnumber. So the result of 3 + 2.0 is 5.0

# %% [markdown]
# #### Exercise-2: Use the internet and search for Python variable types (https://www.inferentialthinking.com/chapters/04/Data_Types.html)
#
# **Create a simple script that illustrates the following types of variables**
#
# - **integer**
# - **floating point (real)**
# - **string (alphanumeric)**
# - **boolean**
#
# **by**
#
# **1. Assigning a value to a string, integer, float, and boolean variable.  Use meaningful names for each variable.**
# **2. Print the contents of each variable.**

# %% [markdown]
# **(20 points)**

# %%
int = 15 #integer
float = 42.67  #float
str = "I love Texas Tech" #string

is_weekday = True   #Boolean
is_weekend = False

if is_weekday:
    print("you have school today")
else:
    print("you dont have school today")

if is_weekend:
    print("enjoy your weekend!")
else:
    print("get ready for school")

print(int)
print(float)
print(str)
# Out:
# you have school today
# get ready for school
# 15
# 42.67
# I love Texas Tech

# %% [markdown]
# #### Exercise-3: Run the code cell below.  Now, calculate the expressions in the code cell below by hand and see if your output matches the Python output.

# %% [markdown]
# **(20 points)**

# %%
x1 = 7 + 3 * 6 / 2 - 1
x2 = 2 % 2 + 2 * 2 - 2 / 2
x3 = ( 3 * 9 * ( 3 + ( 9 * 3 / ( 3 ) ) ) )

print("x1:", x1)
print("x2:", x2)
print("x3:", x3)
#hand calculation: x1(3*6=18 18/2=9 9+7=16 16-1 = 15)  x2(2%2=0(no remainder) 2*2=4 2/2=1 4-1 = 3) x3(9*3/3=9 3+9=12 3*9*12=324)
# Out:
# x1: 15.0
# x2: 3.0
# x3: 324.0

# %% [markdown]
# #### Exercise-4: Get two floating point numbers via the input() function and store them under the variable names 'float1' and 'float2'.  Print 'float1' and 'float2' to the output screen.  Following this, check whether 'float1' is greater than or equal to 'float2'.

# %% [markdown]
# **(20 points)**

# %%
float1 = input("Enter 1st float here:")
float2 = input("Enter 2nd float here:")
print("float1:", float1)
print("float2:", float2)

if float1>float2:
    print("float1 is greater than float2")
else:
    print("float1 is less than float2")
# Out:
# Enter 1st float here:7.34
# Enter 2nd float here:4.26
# float1: 7.34
# float2: 4.26
# float1 is greater than float2

# %% [markdown]
# #### Exercise-5: Define the string given below in quotes to a meaningul variable name.
#
# **'Computational Thinking'**
#
# **After initializing the variable:**
#
# **1. Index and print all the elements from index positions 2 to 10.**
#
# **2. Index and print the string 'Think' from 'Computational Thinking'.**

# %% [markdown]
# **(20 points)**

# %%
s1='Computational Thinking'
s2=s1[2:10]
s3=s1[14:19]
print(s1)
print(s2)
print(s3)
# Out:
# Computational Thinking
# mputatio
# Think
