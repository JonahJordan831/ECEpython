# %% [markdown]
# # <font color=darkblue>Week 2 Assignment </font>

# %% [markdown]
# ## Full name: Jonah Jordan
# ## R#: 11886590
# ## Title of the notebook: Assignment 2
# ## Date: 9/18/23

# %%
# RUN this cell only, do not modify it
import sys
! hostname
! whoami
print(sys.executable)
print(sys.version)
print(sys.version_info)
# Out:
# Jonah_laptop
# jonah_laptop\jonah
# C:\Users\JONAH\anaconda3\python.exe
# 3.11.4 | packaged by Anaconda, Inc. | (main, Jul  5 2023, 13:38:37) [MSC v.1916 64 bit (AMD64)]
# sys.version_info(major=3, minor=11, micro=4, releaselevel='final', serial=0)

# %% [markdown]
# ![](https://cdn.dribbble.com/users/846207/screenshots/9192312/office-desk-animation.gif) <br>

# %% [markdown]
# ## Question0: Think, Design, Draw, Code!  <br>
#
# ### For the problem described below, follow the steps:
#
# #### The problem statement:
# > "Calculate the multiplication of any three numbers and report whether it is an even number or not."

# %% [markdown]
# ### A) Think about your solution (algorithm) and design your flowchart. Draw your flowchart (either on paper or in a software (PowerPoint) and attach a screenshot.

# %% [markdown]
# ---
# EDIT THIS MARKDOWN CELL
# ![processed-9BB62030-85D7-4DE1-BB67-FA02A62109FC-02B1284E-5D07-475E-90B7-16AAE4B0DD4D.jpeg](attachment:processed-9BB62030-85D7-4DE1-BB67-FA02A62109FC-02B1284E-5D07-475E-90B7-16AAE4B0DD4D.jpeg)
#
# ---

# %% [markdown]
# ### B) Based on your flowchart, write the pseudocode based on what we discussed.

# %% [markdown]
# ---
# - enter 3 integers
# - multiply the 3 integers
# - divide the integers by 2
# - check if the number is whole
# - if yes print "even"
# - if no print "odd"
#
#
# ---

# %% [markdown]
# ### C) Based on your pseudocode, write your code in Python.

# %%
n1=int(input("Input first number here"))
n2=int(input("Input second number here"))
n3=int(input("Input third number here"))


product = int(n1*n2*n3)

if product %2 == 0:
    print("the number is even")
else :
    print("the number is odd")
# Out:
# Input first number here2
# Input second number here4
# Input third number here6
# even

# %% [markdown]
# ### D) Test your code for these cases:
#
# - a) 10,2,1
# - b) 3,5,7
# - c) 4,6,8

# %%
n1=int(input("Input first number here"))
n2=int(input("Input second number here"))
n3=int(input("Input third number here"))


product = int(n1*n2*n3)

if product %2 == 0:
    print("the number is even")
else :
    print("the number is odd")
# Out:
# Input first number here10
# Input second number here2
# Input third number here1
# the number is even

# %%
n1=int(input("Input first number here"))
n2=int(input("Input second number here"))
n3=int(input("Input third number here"))


product = int(n1*n2*n3)

if product %2 == 0:
    print("the number is even")
else :
    print("the number is odd")
# Out:
# Input first number here3
# Input second number here5
# Input third number here7
# the number is odd

# %%
n1=int(input("Input first number here"))
n2=int(input("Input second number here"))
n3=int(input("Input third number here"))


product = int(n1*n2*n3)

if product %2 == 0:
    print("the number is even")
else :
    print("the number is odd")
# Out:
# Input first number here4
# Input second number here6
# Input third number here8
# the number is even

# %% [markdown]
# ### E) What kind of structures did you use? sequential? selection? or both? why?

# %% [markdown]
# ---
# EDIT THIS MARKDOWN CELL
# It is both, At the begining it is sequiential putting in the inputs, but the "if,else" selection is a selection. This is because the code would not work if there was only a sequential or a selection aspect.
#
# ---

# %% [markdown]
# ___
# ___

# %% [markdown]
# ## Question1: A Weird Lottery <br>
#
#
# ### Write a code based on the desciption below:
#
# > Receive a 10-digit lottery ticket number from user, <br>
#     if the number is equal to **"2205636346"**, print **"You are the lucky winner of 10 Million Dollars!"** <br>
#     if the number is equal to **"1010101010"**, print **"You are the unlucky winner of a bullet! Bang!"** <br>
#     if the number is any other ***even number***, print **"You win a chocolate dipped hotdog!"** <br>
#     if the number is any ***odd number***, print **"you are odd!"** <br>

# %%
import random

random_number = random.randint(10**9, 10**10 - 1)

print(random_number)


if random_number == int(2205636346):
    print("You are the lucky winner of 10 Million Dollars!")
elif random_number == int(1010101010):
    print("You are the unlucky winner of a bullet! Bang!")
elif random_number%2 == 0:
    print("You win a chocolate dipped hotdog!")
else :
    print("you are odd!")
# Out:
# 4108658974
# You win a chocolate dipped hotdog!

# %% [markdown]
# ## Question2: What if if if ... <br>
#
#
# ### Write a code based on the desciption below:
#
# > Receive an integer from user between 0 to 9, <br>
#     if the number is **greater than 5** and **divisible by 3**, calculate its third power and print the value with an appropriate statement <br>
#     if the number is **lower than 5** and **divisible by 2**, calculate its summation with 10 and print the value with an appropriate statement <br>
#     if the number is **equal to 5**, print **"High Five!"** <br>
#     else, print the number itself <br>
#
# ### Test your code for these cases:
# - a) 6
# - b) 4
# - c) 5
# - d) 0

# %%
user_input = int(input("Enter an integer between 0 and 9: "))

if user_input > 5 and user_input % 3 == 0:
    result = user_input**3
    print(f"{user_input} is greater than 5 and divisible by 3. Its third power is {result}.")
elif user_input <5 and user_input /2:
    result = user_input + 10
    print(f"{user_input} is less than 5 and divisible by 2. Its sum with 10 is {result}.")
elif user_input == 5:
    print("High Five!")
else:
    print(user_input)
# Out:
# Enter an integer between 0 and 9: 6
# 6 is greater than 5 and divisible by 3. Its third power is 216.

# %%
user_input = int(input("Enter an integer between 0 and 9: "))

if user_input > 5 and user_input / 3 == 0:
    result = user_input**3
    print(f"{user_input} is greater than 5 and divisible by 3. Its third power is {result}.")
elif user_input <5 and user_input /2:
    result = user_input + 10
    print(f"{user_input} is less than 5 and divisible by 2. Its sum with 10 is {result}.")
elif user_input == 5:
    print("High Five!")
else:
    print(user_input)
# Out:
# Enter an integer between 0 and 9: 4
# 4 is less than 5 and divisible by 2. Its sum with 10 is 14.

# %%
user_input = int(input("Enter an integer between 0 and 9: "))

if user_input > 5 and user_input / 3 == 0:
    result = user_input**3
    print(f"{user_input} is greater than 5 and divisible by 3. Its third power is {result}.")
elif user_input <5 and user_input /2:
    result = user_input + 10
    print(f"{user_input} is less than 5 and divisible by 2. Its sum with 10 is {result}.")
elif user_input == 5:
    print("High Five!")
else:
    print(user_input)
# Out:
# Enter an integer between 0 and 9: 5
# High Five!

# %%
user_input = int(input("Enter an integer between 0 and 9: "))

if user_input > 5 and user_input / 3 == 0:
    result = user_input**3
    print(f"{user_input} is greater than 5 and divisible by 3. Its third power is {result}.")
elif user_input <5 and user_input /2:
    result = user_input + 10
    print(f"{user_input} is less than 5 and divisible by 2. Its sum with 10 is {result}.")
elif user_input == 5:
    print("High Five!")
else:
    print(user_input)
# Out:
# Enter an integer between 0 and 9: 0
# 0

# %% [markdown]
# ![](https://freight.cargo.site/w/1200/i/c96b2ce17b2aee95c6e837552e3e38d058ac4ad2a6759448ed78128963790744/Happy_Coding_BC_6-03-05.png)
